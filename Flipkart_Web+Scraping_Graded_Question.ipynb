# %% [markdown]
# <a href="https://colab.research.google.com/github/upcomingowner2023/Python-learnings/blob/main/Flipkart_Web%2BScraping_Graded_Question.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## HTML Page Read and Upload

# %%
# Import useful libraries and classes.
from urllib.request import urlopen as uReq
from bs4 import BeautifulSoup as soup

# %%
#html page upload and read in web_page variable.
my_url=  "https://www.flipkart.com/search?p%5B%5D=facets.brand%255B%255D%3DSamsung&sid=tyy%2F4io&sort=recency_desc&wid=1.productCard.PMU_V2_1"
web_page= uReq(my_url)
page_html= web_page.read()

# %% [markdown]
# ## Parsing

# %%
#html parser. It is to beautify the HTML code.
page_soup= soup(page_html,"html.parser")
page_soup
# Out:
# <!DOCTYPE doctype html>
# ...

# %% [markdown]
# ## Extraction of information

# %%
#read class attribute from web page in containers variable.
# Print the length of containers.
containers= page_soup.find_all("div", {"class": "_3pLy-c row"})
print(len(containers))
# Out:
# 24

# %%
print(soup.prettify(containers[0]))
# Out:
# <div class="_3pLy-c row">
#  <div class="col col-7-12">
#   <div class="_4rR01T">
#    SAMSUNG Galaxy S23 5G (Green, 256 GB)
#   </div>
#   <div class="fMghEO">
#    <ul class="_1xgFaf">
#     <li class="rgWa7D">
#      8 GB RAM | 256 GB ROM
#     </li>
#     <li class="rgWa7D">
#      15.49 cm (6.1 inch) Full HD+ Display
#     </li>
#     <li class="rgWa7D">
#      50MP + 10MP + 12MP | 12MP Front Camera
#     </li>
#     <li class="rgWa7D">
#      3900 mAh Lithium Ion Battery
#     </li>
#     <li class="rgWa7D">
#      Qualcomm Snapdragon 8 Gen 2 Processor
#     </li>
#     <li class="rgWa7D">
#      1 Year Manufacturer Warranty for Device and 6 Months Manufacturer Warranty for In-Box Accessories
#     </li>
#    </ul>
#   </div>
#  </div>
#  <div class="col col-5-12 nlI3QM">
#   <div class="_3tbKJL">
#    <div class="_25b18c">
#     <div class="_30jeq3 _1_WHN1">
#      ₹79,999
#     </div>
#     <div class="_3I9_wc _27UcVY">
#      ₹
#      <!-- -->
#      95,999
#     </div>
# ...

# %%
# Extract the model name of 6th phone in the list.
mobile_name=containers[5].findAll("div",{"class": "_4rR01T"})
print(mobile_name[0].text.strip())
# Out:
# SAMSUNG Galaxy S23 Plus 5G (Phantom Black, 512 GB)

# %%
# how many elements does 'tVe95H' class contained in it?
specs_phone=containers[7].findAll("li",{"class":"rgWa7D"})
print(specs_phone[2].text.strip())
# Out:
# 200MP + 10MP + 12MP + 10MP | 12MP Front Camera

# %%
# Read the camera specification of 8th phone in the list.
